# %% [markdown]
# # Original Data

# %%
import pyreadr
# pyreadr stuff are imported as a pandas df
original_data = pyreadr.read_r("../data/allSyntheticData.RData")

for key in original_data.keys():
    print(key)


original_data["x"].describe()
# Out:
# x
# y
# GMM_synthetic
# MVN_synthetic
# KNN_synthetic_k3
# KNN_synthetic_koptimal
# KNN_synthetic_k20
# x.ROSE
#        spikeProduction_D1D2  spikeDecay_D1D2  spikeProduction_D3  \
# count             91.000000        91.000000           91.000000
# mean               3.140900         0.024470            0.623535
# std                0.129185         0.000957            0.004086
# min                2.719030         0.022410            0.611582
# 25%                3.027450         0.023676            0.620904
# 50%                3.166710         0.024468            0.623674
# 75%                3.244825         0.024960            0.625776
# max                3.374490         0.027429            0.636512
#
#        spikeDecay_D3  RBDProduction_D1D2  RBDDecay_D1D2  RBDProduction_D3  \
# count      91.000000           91.000000      91.000000         91.000000
# mean        0.008704            2.404523       0.021559          0.816986
# std         0.000240            0.100926       0.000241          0.023165
# min         0.007868            2.041320       0.020824          0.755502
# 25%         0.008590            2.370940       0.021409          0.807806
# 50%         0.008685            2.421640       0.021546          0.815788
# 75%         0.008837            2.457020       0.021703          0.832695
# max         0.009499            2.636030       0.022297          0.877846
#
#        RBDDecay_D3  V1_blood_IgGspike  V4_blood_IgGspike  ...     V8Dual  \
# count    91.000000          91.000000          91.000000  ...  91.000000
# mean      0.011377           6.896112         203.005636  ...   8.972802
# std       0.000225           7.564040         286.218281  ...  11.373209
# min       0.010854           1.130000           1.130000  ...   0.000000
# 25%       0.011216           2.840000          49.150000  ...   2.500000
# 50%       0.011419           4.845800         121.120000  ...   5.250000
# 75%       0.011514           7.787900         207.093300  ...  10.000000
# max       0.012038          46.400000        1500.800000  ...  82.500000
#
#        IFNG_production  Il2_production  RATIO_CD4CD8       V8Neut  \
# count        91.000000       91.000000     91.000000    91.000000
# mean          0.092249        0.233814      1.265479   265.097651
# std           0.086882        0.129049      0.970174   332.993133
# min           0.003646        0.049692      0.227273     0.000000
# 25%           0.024860        0.123947      0.616667    77.190000
# 50%           0.051310        0.230365      1.010000   154.400000
# 75%           0.144509        0.302620      1.541667   320.000000
# max           0.442075        0.820327      5.460000  1280.000000
#
#             V9Neut      V7_ACE2      V8_ACE2     V8b_ACE2      V9_ACE2
# count    91.000000    91.000000    91.000000    91.000000    91.000000
# mean    935.714091   334.412549   136.175880   694.119204   523.224070
# std     996.514247   358.293623   147.367927   469.880154   512.892294
# min       0.000000    50.060000    50.060000    50.060000    50.060000
# 25%     157.200000   103.403600    50.060000   312.275000   140.904000
# 50%     331.700000   244.262000    57.407900   527.106200   290.150000
# 75%    1818.000000   352.510000   199.657550  1033.178550   974.808350
# max    2560.000000  1520.290000  1069.370000  1520.290000  1520.290000
#
# [8 rows x 63 columns]

# %%
print(original_data["x"].iloc[:,2])
print(original_data["GMM_synthetic"].iloc[:, 2])
# Out:
# 0     0.625745
# 1     0.628603
# 2     0.626565
# 3     0.622260
# 4     0.623358
#         ...
# 86    0.619925
# 87    0.620110
# 88    0.622747
# 89    0.624022
# 90    0.621006
# Name: spikeProduction_D3, Length: 91, dtype: float64
# 0     0.623706
# 1     0.628594
# 2     0.626568
# 3     0.624712
# 4     0.624877
#         ...
# 86    0.622135
# 87    0.628087
# 88    0.621142
# 89    0.624168
# 90    0.626225
# Name: spikeProduction_D3, Length: 91, dtype: float64

# %% [markdown]
# # CVAE Synthetic Data

# %%
import numpy as np

my_data_file = "../data/log1p/samples/cvae_synth_seed42_y0.npz"
my_data1 = np.load(my_data_file)
my_data_file = "../data/log1p/samples/cvae_synth_seed42_y1.npz"
my_data2 = np.load(my_data_file)

# %%
import pandas as pd

col_name = original_data["x"].columns

cvae_y0 = pd.DataFrame(my_data1["X"], columns=col_name)
cvae_y1 = pd.DataFrame(my_data2["X"], columns=col_name)

# %% [markdown]
# ## Comparison real vs. cvae

# %%
from IPython.display import Markdown
display(Markdown("## Original Dataset"))
display(original_data["x"].describe())

display(Markdown("## CVAE Synthetic Dataset"))
display(cvae_y0.describe())
# Out:
# ## Original Dataset
#        spikeProduction_D1D2  spikeDecay_D1D2  spikeProduction_D3  \
# count             91.000000        91.000000           91.000000
# mean               3.140900         0.024470            0.623535
# std                0.129185         0.000957            0.004086
# min                2.719030         0.022410            0.611582
# 25%                3.027450         0.023676            0.620904
# 50%                3.166710         0.024468            0.623674
# 75%                3.244825         0.024960            0.625776
# max                3.374490         0.027429            0.636512
#
#        spikeDecay_D3  RBDProduction_D1D2  RBDDecay_D1D2  RBDProduction_D3  \
# count      91.000000           91.000000      91.000000         91.000000
# mean        0.008704            2.404523       0.021559          0.816986
# std         0.000240            0.100926       0.000241          0.023165
# min         0.007868            2.041320       0.020824          0.755502
# 25%         0.008590            2.370940       0.021409          0.807806
# 50%         0.008685            2.421640       0.021546          0.815788
# 75%         0.008837            2.457020       0.021703          0.832695
# max         0.009499            2.636030       0.022297          0.877846
#
#        RBDDecay_D3  V1_blood_IgGspike  V4_blood_IgGspike  ...     V8Dual  \
# count    91.000000          91.000000          91.000000  ...  91.000000
# mean      0.011377           6.896112         203.005636  ...   8.972802
# std       0.000225           7.564040         286.218281  ...  11.373209
# min       0.010854           1.130000           1.130000  ...   0.000000
# 25%       0.011216           2.840000          49.150000  ...   2.500000
# 50%       0.011419           4.845800         121.120000  ...   5.250000
# 75%       0.011514           7.787900         207.093300  ...  10.000000
# max       0.012038          46.400000        1500.800000  ...  82.500000
#
#        IFNG_production  Il2_production  RATIO_CD4CD8       V8Neut  \
# count        91.000000       91.000000     91.000000    91.000000
# mean          0.092249        0.233814      1.265479   265.097651
# std           0.086882        0.129049      0.970174   332.993133
# min           0.003646        0.049692      0.227273     0.000000
# 25%           0.024860        0.123947      0.616667    77.190000
# 50%           0.051310        0.230365      1.010000   154.400000
# 75%           0.144509        0.302620      1.541667   320.000000
# max           0.442075        0.820327      5.460000  1280.000000
#
#             V9Neut      V7_ACE2      V8_ACE2     V8b_ACE2      V9_ACE2
# count    91.000000    91.000000    91.000000    91.000000    91.000000
# mean    935.714091   334.412549   136.175880   694.119204   523.224070
# std     996.514247   358.293623   147.367927   469.880154   512.892294
# min       0.000000    50.060000    50.060000    50.060000    50.060000
# 25%     157.200000   103.403600    50.060000   312.275000   140.904000
# 50%     331.700000   244.262000    57.407900   527.106200   290.150000
# 75%    1818.000000   352.510000   199.657550  1033.178550   974.808350
# max    2560.000000  1520.290000  1069.370000  1520.290000  1520.290000
#
# [8 rows x 63 columns]
# ## CVAE Synthetic Dataset
#        spikeProduction_D1D2  spikeDecay_D1D2  spikeProduction_D3  \
# count             91.000000        91.000000           91.000000
# mean               3.147187         0.024459            0.623796
# std                0.053859         0.000410            0.001678
# min                3.026428         0.023292            0.620409
# 25%                3.109829         0.024194            0.622461
# 50%                3.146290         0.024437            0.623827
# 75%                3.186965         0.024754            0.624912
# max                3.282241         0.025317            0.627743
#
#        spikeDecay_D3  RBDProduction_D1D2  RBDDecay_D1D2  RBDProduction_D3  \
# count      91.000000           91.000000      91.000000         91.000000
# mean        0.008646            2.397339       0.021626          0.816573
# std         0.000078            0.039265       0.000065          0.010830
# min         0.008483            2.295986       0.021509          0.795572
# 25%         0.008592            2.371961       0.021571          0.809569
# 50%         0.008642            2.393273       0.021628          0.816524
# 75%         0.008708            2.420157       0.021670          0.821801
# max         0.008824            2.505405       0.021810          0.845795
#
#        RBDDecay_D3  V1_blood_IgGspike  V4_blood_IgGspike  ...     V8Dual  \
# count    91.000000          91.000000          91.000000  ...  91.000000
# mean      0.011380           5.911865         132.652283  ...   4.375254
# std       0.000111           2.064185          60.500160  ...   2.023834
# min       0.011054           3.087928          28.966131  ...   0.949891
# 25%       0.011313           4.578019          93.481724  ...   2.950508
# 50%       0.011381           5.452377         117.414070  ...   4.241226
# 75%       0.011464           6.732165         160.782326  ...   5.267595
# max       0.011583          13.120099         345.998474  ...  13.812159
#
#        IFNG_production  Il2_production  RATIO_CD4CD8      V8Neut       V9Neut  \
# count        91.000000       91.000000     91.000000   91.000000    91.000000
# mean          0.029627        0.126372      1.821618  336.717499   401.246063
# std           0.020169        0.034513      0.336019  147.945068   301.231812
# min          -0.034178        0.058487      1.046068  110.760391    32.053360
# 25%           0.017263        0.102389      1.616976  213.740837   206.515816
# 50%           0.030806        0.121486      1.775549  329.474182   302.263489
# 75%           0.043173        0.145933      1.994910  442.734848   493.451279
# max           0.070908        0.214743      2.671396  797.027649  1760.608032
#
#           V7_ACE2     V8_ACE2     V8b_ACE2      V9_ACE2
# count   91.000000   91.000000    91.000000    91.000000
# mean   194.605637   84.287514   583.152832   254.611542
# std     72.854866   29.096592   166.602844   157.330887
# min     74.451508   40.381725   270.087921    70.241745
# 25%    138.855461   63.268051   464.709396   150.412537
# 50%    184.417145   78.983032   556.237122   211.662506
# 75%    226.663651   99.212975   673.167755   305.318039
# max    458.721100  203.642929  1128.896729  1012.792419
#
# [8 rows x 63 columns]

# %% [markdown]
# # After running rf

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold, cross_val_score

oX = original_data["x"]
oy = original_data["y"]

store_max = {}

# y has to be 1D because right now it includes index
if len(oy.shape) == 2:
    oy = oy.iloc[:, 0]
oy = oy.astype(int)

real_y0 = oX.loc[oy == 0]
real_y1 = oX.loc[oy == 1]
syn_y0 = cvae_y0
syn_y1 = cvae_y1

syn_X = pd.concat([syn_y0, syn_y1], axis=0, ignore_index=True)
for col in oX.columns:
    q99 = oX[col].quantile(0.99)
    max_val = oX[col].max()
    store_max[col] = max_val
    # max approximately equals 99th percentile
    if abs(max_val - q99) < 1e-6: 
        print(col, max_val)
# Out:
# V6_blood_IgGspike 1500.8
# V8_blood_IgGspike 1500.8
# V8a_blood_IgGspike 1500.8
# V8b_blood_IgGspike 1500.8
# V9_blood_IgGspike 1500.8
# V10_blood_IgGspike 1500.8
# V11_blood_IgGspike 1500.8
# V6_blood_IgGRBD 4453.99
# V8_blood_IgGRBD 4453.99
# V8b_blood_IgGRBD 4453.99
# V9_blood_IgGRBD 4453.99
# V10_blood_IgGRBD 4453.99
# V11_blood_IgGRBD 4453.99
# V9Neut 2560.0
# V7_ACE2 1520.29
# V8b_ACE2 1520.29
# V9_ACE2 1520.29

# %%
from matplotlib import pyplot as plt


def summarize_feature(real: pd.Series, syn: pd.Series, ceiling=None, name=""):
    qs = [0.5, 0.9, 0.95, 0.99]
    out = {
        "feature": name,
        "real_mean": real.mean(),
        "syn_mean": syn.mean(),
        "real_std": real.std(),
        "syn_std": syn.std(),
    }
    for q in qs:
        out[f"real_q{int(q*100)}"] = real.quantile(q)
        out[f"syn_q{int(q*100)}"] = syn.quantile(q)
    if ceiling is not None:
        out["real_p_at_ceiling"] = (real == ceiling).mean()
        out["syn_p_at_ceiling"] = (syn == ceiling).mean()
    return out

import numpy as np

def plot_feature(real, syn, title="", bins=60, ceiling=None):
    plt.figure()

    all_vals = np.r_[real.values, syn.values]
    edges = np.histogram_bin_edges(all_vals, bins=bins)

    plt.hist(real.values, bins=edges, alpha=0.5, density=True, label="real")
    plt.hist(syn.values,  bins=edges, alpha=0.5, density=True, label="synthetic")
    if ceiling is not None:
        plt.axvline(ceiling, linestyle="--")

    plt.title(title)
    plt.xlabel("Value")
    plt.ylabel("Denisties")
    plt.legend()
    plt.show()

feat = "V10_blood_IgGRBD"
CEILING = store_max[feat] 

# y=0
summ_y0 = summarize_feature(real_y0[feat], syn_y0[feat], ceiling=CEILING, name=f"{feat} (y=0)")
# y=1
summ_y1 = summarize_feature(real_y1[feat], syn_y1[feat], ceiling=CEILING, name=f"{feat} (y=1)")

display(pd.DataFrame([summ_y0, summ_y1]))

plot_feature(
    real_y0[feat],
    syn_y0[feat],
    title=f"{feat} Distribution (y=0)",
    ceiling=CEILING
)

plot_feature(
    real_y1[feat],
    syn_y1[feat],
    title=f"{feat} Distribution (y=1)",
    ceiling=CEILING
)
# Out:
#                   feature    real_mean     syn_mean     real_std     syn_std  \
# 0  V10_blood_IgGRBD (y=0)  1333.697826   562.346802  1656.200352  405.088623
# 1  V10_blood_IgGRBD (y=1)  1877.939871  1078.815063  1734.593193  888.058533
#
#      real_q50     syn_q50  real_q90      syn_q90  real_q95      syn_q95  \
# 0   319.85000  450.315613  4107.974  1000.633179  4427.433  1160.471252
# 1  1078.32215  718.092896  4453.990  2461.486816  4453.990  2940.653442
#
#    real_q99      syn_q99  real_p_at_ceiling  syn_p_at_ceiling
# 0   4453.99  2253.685547           0.086957               0.0
# 1   4453.99  4184.419238           0.235294               0.0

# %%
def ensure_df(X, columns):
    """Make sure X is a DataFrame with the given columns."""
    if isinstance(X, pd.DataFrame):
        return X[columns].copy()
    return pd.DataFrame(X, columns=columns)

def rf_auc_probe_binary(real_df: pd.DataFrame, syn_df: pd.DataFrame, seed=42, n_splits=5):
    """
    RF probe: label s=0 real, s=1 synthetic.
    Returns mean/std AUC via stratified CV.
    """
    n = min(len(real_df), len(syn_df))
    rng = np.random.default_rng(seed)

    # sample same n from each
    real_idx = rng.choice(real_df.index.to_numpy(), size=n, replace=False)
    syn_idx  = rng.choice(syn_df.index.to_numpy(),  size=n, replace=False)

    real_s = real_df.loc[real_idx]
    syn_s  = syn_df.loc[syn_idx]

    X = pd.concat([real_s, syn_s], axis=0).to_numpy()
    s = np.r_[np.zeros(n, dtype=int), np.ones(n, dtype=int)]

    rf = RandomForestClassifier(
        n_estimators=500,
        max_depth=None,
        random_state=seed,
        n_jobs=-1,
    )

    cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=seed)
    aucs = cross_val_score(rf, X, s, cv=cv, scoring="roc_auc")

    return float(aucs.mean()), float(aucs.std()), aucs

# Per-stratum probes 

cols = oX.columns

syn_y0_df = ensure_df(syn_y0, cols)
syn_y1_df = ensure_df(syn_y1, cols)

real_y0_df = ensure_df(real_y0, cols)
real_y1_df = ensure_df(real_y1, cols)

auc0_mean, auc0_std, auc0_folds = rf_auc_probe_binary(real_y0_df, syn_y0_df, seed=42)
auc1_mean, auc1_std, auc1_folds = rf_auc_probe_binary(real_y1_df, syn_y1_df, seed=42)

print(f"RF AUC (y=0): {auc0_mean:.3f} ± {auc0_std:.3f}   folds={np.round(auc0_folds,3)}")
print(f"RF AUC (y=1): {auc1_mean:.3f} ± {auc1_std:.3f}   folds={np.round(auc1_folds,3)}")
# Out:
# RF AUC (y=0): 0.990 ± 0.020   folds=[1.   1.   1.   1.   0.95]
# RF AUC (y=1): 0.976 ± 0.021   folds=[0.99  0.94  1.    0.984 0.967]

# %% [markdown]
# # Ablation section

# %%
real_X = oX
real_y = oy

syn_X = pd.concat([syn_y0, syn_y1], axis=0, ignore_index=True)
syn_y = np.r_[
    np.zeros(len(syn_y0), dtype=int),
    np.ones(len(syn_y1), dtype=int)
]

# Balanced counts for probe
n_neg = min((real_y == 0).sum(), (syn_y == 0).sum())
n_pos = min((real_y == 1).sum(), (syn_y == 1).sum())

# %%
rng = np.random.default_rng(42)

def strat_samp(neg_i, posi_i, n_neg, n_posi):
    chosen_neg = rng.choice(neg_i, size=n_neg, replace=False)
    chosen_posi = rng.choice(posi_i, size=n_posi, replace=False)
    return np.concatenate([chosen_neg, chosen_posi])

def rf_auc_probe_stratified(real_X: pd.DataFrame, real_y,
                             syn_X: pd.DataFrame, syn_y,
                             n_neg, n_pos, seed=42):

    real_y = np.asarray(real_y).astype(int)
    syn_y  = np.asarray(syn_y).astype(int)

    # indices per stratum
    real_neg_i = np.where(real_y == 0)[0]
    real_pos_i = np.where(real_y == 1)[0]

    syn_neg_i = np.where(syn_y == 0)[0]
    syn_pos_i = np.where(syn_y == 1)[0]

    # stratified sampling
    real_idx = strat_samp(real_neg_i, real_pos_i, n_neg, n_pos)
    syn_idx  = strat_samp(syn_neg_i,  syn_pos_i,  n_neg, n_pos)

    real_s = real_X.iloc[real_idx]
    syn_s  = syn_X.iloc[syn_idx]

    X = pd.concat([real_s, syn_s], axis=0).to_numpy()
    s = np.r_[np.zeros(len(real_s), dtype=int),
              np.ones(len(syn_s), dtype=int)]

    rf = RandomForestClassifier(
        n_estimators=500,
        random_state=seed,
        n_jobs=-1
    )

    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
    aucs = cross_val_score(rf, X, s, cv=cv, scoring="roc_auc")

    return float(aucs.mean()), float(aucs.std()), aucs

# %% [markdown]
# # Ablation function

# %%
def run_ablation(real_X, real_y, syn_X, syn_y, drop_feats, n_neg, n_pos, seed=42, label=""):
    # keep only features that exist
    drop_feats = [f for f in drop_feats if f in real_X.columns]

    real_ab = real_X.drop(columns=drop_feats)
    syn_ab  = syn_X.drop(columns=drop_feats)

    auc_mean, auc_std, folds = rf_auc_probe_stratified(
        real_X=real_ab,
        real_y=real_y,
        syn_X=syn_ab,
        syn_y=syn_y,
        n_neg=n_neg,
        n_pos=n_pos,
        seed=seed
    )

    print(f"[{label}] dropped {len(drop_feats)} features")
    print(f"  AUC: {auc_mean:.3f} ± {auc_std:.3f}  folds={np.round(folds,3)}")

    return auc_mean, auc_std, folds, drop_feats

# %% [markdown]
# ### No Ablation Model

# %%
auc0, sd0, folds0 = rf_auc_probe_stratified(real_X, real_y, syn_X, syn_y, n_neg, n_pos)
print(f"[baseline] AUC: {auc0:.3f} ± {sd0:.3f}  folds={np.round(folds0,3)}")
# Out:
# [baseline] AUC: 0.969 ± 0.031  folds=[0.98  1.    0.988 0.912 0.966]

# %%
drop_igg = [c for c in real_X.columns if "IgG" in c]
run_ablation(real_X, real_y, syn_X, syn_y, drop_igg, n_neg, n_pos, label="drop all IgG*")
# Out:
# [drop all IgG*] dropped 30 features
#   AUC: 0.971 ± 0.014  folds=[0.962 0.985 0.963 0.989 0.954]
# (0.9706465237166991,
#  0.014016273819453601,
#  array([0.9619883 , 0.98538012, 0.96296296, 0.98919753, 0.9537037 ]),
#  ['V1_blood_IgGspike',
#   'V4_blood_IgGspike',
#   'V4a_blood_IgGspike',
#   'V6_blood_IgGspike',
#   'V8_blood_IgGspike',
#   'V8a_blood_IgGspike',
#   'V8b_blood_IgGspike',
#   'V9_blood_IgGspike',
#   'V10_blood_IgGspike',
#   'V11_blood_IgGspike',
#   'V1_blood_IgGRBD',
#   'V4_blood_IgGRBD',
#   'V4a_blood_IgGRBD',
#   'V6_blood_IgGRBD',
#   'V8_blood_IgGRBD',
#   'V8a_blood_IgGRBD',
#   'V8b_blood_IgGRBD',
#   'V9_blood_IgGRBD',
#   'V10_blood_IgGRBD',
#   'V11_blood_IgGRBD',
#   'V4_Saliva_IgGspike',
#   'V4_Saliva_IgGRBD',
#   'V5_Saliva_IgGspike',
#   'V5_Saliva_IgGRBD',
#   'V8_Saliva_IgGspike',
#   'V8_Saliva_IgGRBD',
#   'V8b_Saliva_IgGspike',
#   'V8b_Saliva_IgGRBD',
#   'V9_Saliva_IgGspike',
#   'V9_Saliva_IgGRBD'])

# %% [markdown]
# # RF-driven ablation

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score

def fit_rf_get_importance(real_X, real_y, syn_X, syn_y, n_neg, n_pos, seed=42):
    real_y = np.asarray(real_y).astype(int)
    syn_y  = np.asarray(syn_y).astype(int)

    real_neg_i = np.where(real_y == 0)[0]
    real_pos_i = np.where(real_y == 1)[0]
    syn_neg_i  = np.where(syn_y == 0)[0]
    syn_pos_i  = np.where(syn_y == 1)[0]

    real_idx = strat_samp(real_neg_i, real_pos_i, n_neg, n_pos)
    syn_idx  = strat_samp(syn_neg_i,  syn_pos_i,  n_neg, n_pos)

    real_s = real_X.iloc[real_idx]
    syn_s  = syn_X.iloc[syn_idx]

    X = pd.concat([real_s, syn_s], axis=0)
    s = np.r_[np.zeros(len(real_s), dtype=int), np.ones(len(syn_s), dtype=int)]

    rf = RandomForestClassifier(n_estimators=800, random_state=seed, n_jobs=-1)
    rf.fit(X, s)

    imp = pd.Series(rf.feature_importances_, index=X.columns).sort_values(ascending=False)
    return imp

imp = fit_rf_get_importance(real_X, real_y, syn_X, syn_y, n_neg, n_pos)
imp.tail(20)
# Out:
# RBDDecay_D3            0.007193
# V6_blood_IgGRBD        0.007092
# V8b_Saliva_IgAspike    0.007055
# V8b_Saliva_IgARBD      0.007037
# RBDProduction_D3       0.006815
# V4_blood_IgGRBD        0.006783
# V5_Saliva_IgGRBD       0.006493
# V4a_blood_IgGRBD       0.006331
# V8_Saliva_IgAspike     0.006128
# V8a_blood_IgGRBD       0.005910
# V9Dual                 0.005809
# V9_IFNg                0.005660
# spikeProduction_D3     0.005636
# V8_IL2                 0.005100
# V9_Saliva_IgGspike     0.004830
# V8b_Saliva_IgGRBD      0.004817
# V8b_Saliva_IgGspike    0.004616
# Il2_production         0.004583
# V4a_blood_IgGspike     0.004554
# V5_Saliva_IgGspike     0.004426
# dtype: float64

# %%
auc_l= []
k_list = []
for k in range (0, 62):
    drop_k = imp.head(k).index.tolist()
    auc_k, sd_k, folds_k, _ = run_ablation(real_X, real_y, syn_X, syn_y, drop_k, n_neg, n_pos, label=f"drop top {k}")



    k_list.append(k)
    auc_l.append(auc_k)
# Out:
# [drop top 0] dropped 0 features
#   AUC: 0.972 ± 0.041  folds=[1.    0.991 0.89  0.983 0.997]
# [drop top 1] dropped 1 features
#   AUC: 0.980 ± 0.015  folds=[0.988 1.    0.954 0.981 0.977]
# [drop top 2] dropped 2 features
#   AUC: 0.970 ± 0.019  folds=[0.965 0.944 0.988 0.997 0.957]
# [drop top 3] dropped 3 features
#   AUC: 0.972 ± 0.023  folds=[1.    0.963 0.997 0.958 0.941]
# [drop top 4] dropped 4 features
#   AUC: 0.968 ± 0.013  folds=[0.984 0.965 0.966 0.978 0.948]
# [drop top 5] dropped 5 features
#   AUC: 0.972 ± 0.026  folds=[0.994 0.994 0.931 0.954 0.988]
# [drop top 6] dropped 6 features
#   AUC: 0.960 ± 0.019  folds=[0.977 0.931 0.96  0.948 0.985]
# [drop top 7] dropped 7 features
#   AUC: 0.975 ± 0.019  folds=[0.991 0.965 0.944 0.978 0.997]
# [drop top 8] dropped 8 features
#   AUC: 0.949 ± 0.032  folds=[0.975 0.895 0.954 0.985 0.938]
# [drop top 9] dropped 9 features
#   AUC: 0.949 ± 0.035  folds=[0.985 0.901 0.994 0.932 0.932]
# [drop top 10] dropped 10 features
#   AUC: 0.944 ± 0.040  folds=[0.965 0.994 0.968 0.906 0.889]
# [drop top 11] dropped 11 features
#   AUC: 0.955 ± 0.034  folds=[0.991 0.988 0.907 0.963 0.923]
# [drop top 12] dropped 12 features
#   AUC: 0.955 ± 0.024  folds=[0.959 0.921 0.981 0.935 0.978]
# [drop top 13] dropped 13 features
#   AUC: 0.940 ± 0.019  folds=[0.939 0.958 0.932 0.963 0.91 ]
# [drop top 14] dropped 14 features
#   AUC: 0.933 ± 0.028  folds=[0.889 0.95  0.935 0.92  0.972]
# [drop top 15] dropped 15 features
#   AUC: 0.940 ± 0.022  folds=[0.918 0.93  0.954 0.975 0.921]
# [drop top 16] dropped 16 features
#   AUC: 0.925 ± 0.020  folds=[0.939 0.934 0.932 0.886 0.937]
# [drop top 17] dropped 17 features
#   AUC: 0.918 ± 0.035  folds=[0.962 0.906 0.889 0.957 0.877]
# [drop top 18] dropped 18 features
#   AUC: 0.931 ± 0.045  folds=[0.947 0.857 0.965 0.904 0.98 ]
# [drop top 19] dropped 19 features
#   AUC: 0.914 ± 0.027  folds=[0.923 0.906 0.878 0.904 0.96 ]
# [drop top 20] dropped 20 features
#   AUC: 0.909 ± 0.065  folds=[0.959 0.901 0.997 0.877 0.812]
# [drop top 21] dropped 21 features
#   AUC: 0.924 ± 0.046  folds=[0.936 0.944 0.94  0.966 0.833]
# [drop top 22] dropped 22 features
#   AUC: 0.915 ± 0.041  folds=[0.942 0.854 0.904 0.898 0.975]
# [drop top 23] dropped 23 features
#   AUC: 0.908 ± 0.044  folds=[0.944 0.965 0.847 0.912 0.873]
# [drop top 24] dropped 24 features
#   AUC: 0.896 ± 0.038  folds=[0.956 0.848 0.877 0.923 0.877]
# [drop top 25] dropped 25 features
#   AUC: 0.878 ± 0.059  folds=[0.798 0.968 0.852 0.852 0.92 ]
# [drop top 26] dropped 26 features
#   AUC: 0.898 ± 0.060  folds=[0.877 0.95  0.795 0.907 0.96 ]
# [drop top 27] dropped 27 features
#   AUC: 0.887 ± 0.046  folds=[0.882 0.974 0.866 0.836 0.88 ]
# [drop top 28] dropped 28 features
#   AUC: 0.899 ± 0.056  folds=[0.946 0.794 0.929 0.935 0.889]
# [drop top 29] dropped 29 features
#   AUC: 0.891 ± 0.036  folds=[0.848 0.893 0.853 0.92  0.94 ]
# [drop top 30] dropped 30 features
#   AUC: 0.910 ± 0.048  folds=[0.918 0.977 0.855 0.944 0.855]
# [drop top 31] dropped 31 features
#   AUC: 0.875 ± 0.053  folds=[0.841 0.908 0.912 0.787 0.929]
# [drop top 32] dropped 32 features
#   AUC: 0.873 ± 0.059  folds=[0.883 0.858 0.958 0.892 0.775]
# [drop top 33] dropped 33 features
#   AUC: 0.892 ± 0.005  folds=[0.889 0.895 0.9   0.889 0.886]
# [drop top 34] dropped 34 features
#   AUC: 0.887 ± 0.058  folds=[0.905 0.806 0.978 0.85  0.895]
# [drop top 35] dropped 35 features
#   AUC: 0.898 ± 0.062  folds=[0.98  0.854 0.81  0.894 0.954]
# [drop top 36] dropped 36 features
#   AUC: 0.843 ± 0.049  folds=[0.86  0.766 0.812 0.87  0.907]
# [drop top 37] dropped 37 features
#   AUC: 0.858 ± 0.062  folds=[0.917 0.743 0.866 0.861 0.904]
# [drop top 38] dropped 38 features
#   AUC: 0.818 ± 0.053  folds=[0.776 0.763 0.826 0.813 0.914]
# [drop top 39] dropped 39 features
#   AUC: 0.835 ± 0.070  folds=[0.906 0.791 0.87  0.886 0.719]
# [drop top 40] dropped 40 features
#   AUC: 0.871 ± 0.038  folds=[0.914 0.852 0.889 0.895 0.807]
# [drop top 41] dropped 41 features
#   AUC: 0.814 ± 0.083  folds=[0.87  0.924 0.708 0.84  0.728]
# [drop top 42] dropped 42 features
#   AUC: 0.829 ± 0.060  folds=[0.899 0.801 0.841 0.873 0.728]
# [drop top 43] dropped 43 features
#   AUC: 0.848 ± 0.015  folds=[0.819 0.855 0.86  0.855 0.852]
# [drop top 44] dropped 44 features
#   AUC: 0.863 ± 0.064  folds=[0.83  0.871 0.972 0.864 0.778]
# [drop top 45] dropped 45 features
#   AUC: 0.841 ± 0.040  folds=[0.797 0.893 0.795 0.843 0.877]
# [drop top 46] dropped 46 features
#   AUC: 0.861 ± 0.049  folds=[0.827 0.899 0.826 0.815 0.938]
# [drop top 47] dropped 47 features
#   AUC: 0.843 ± 0.040  folds=[0.77  0.882 0.87  0.858 0.833]
# [drop top 48] dropped 48 features
#   AUC: 0.825 ± 0.070  folds=[0.734 0.877 0.867 0.745 0.9  ]
# [drop top 49] dropped 49 features
#   AUC: 0.835 ± 0.045  folds=[0.892 0.801 0.819 0.883 0.778]
# [drop top 50] dropped 50 features
#   AUC: 0.798 ± 0.089  folds=[0.76  0.658 0.81  0.927 0.833]
# [drop top 51] dropped 51 features
#   AUC: 0.803 ± 0.062  folds=[0.708 0.901 0.798 0.818 0.792]
# [drop top 52] dropped 52 features
#   AUC: 0.784 ± 0.060  folds=[0.889 0.766 0.725 0.807 0.731]
# [drop top 53] dropped 53 features
#   AUC: 0.800 ± 0.046  folds=[0.86  0.735 0.835 0.807 0.761]
# [drop top 54] dropped 54 features
#   AUC: 0.754 ± 0.088  folds=[0.803 0.868 0.792 0.688 0.62 ]
# [drop top 55] dropped 55 features
#   AUC: 0.791 ± 0.097  folds=[0.749 0.813 0.81  0.642 0.941]
# [drop top 56] dropped 56 features
#   AUC: 0.800 ± 0.033  folds=[0.835 0.845 0.765 0.776 0.781]
# [drop top 57] dropped 57 features
#   AUC: 0.737 ± 0.063  folds=[0.617 0.787 0.781 0.772 0.728]
# [drop top 58] dropped 58 features
#   AUC: 0.745 ± 0.063  folds=[0.781 0.623 0.745 0.779 0.795]
# [drop top 59] dropped 59 features
#   AUC: 0.776 ± 0.056  folds=[0.833 0.781 0.823 0.676 0.765]
# [drop top 60] dropped 60 features
#   AUC: 0.690 ± 0.049  folds=[0.754 0.732 0.636 0.634 0.693]
# [drop top 61] dropped 61 features
#   AUC: 0.652 ± 0.039  folds=[0.659 0.649 0.583 0.665 0.702]

# %%
display(Markdown("### Log plus Normalized RF Importance"))
plt.figure()
plt.plot(k_list, auc_l, marker="o")

plt.xlabel("Number of Top Features Dropped")
plt.ylabel("AUC")
plt.title("Ablation of Top Features by RF Importance (Log)")
plt.show()
# Out:
# ### Log plus Normalized RF Importance

# %%
import matplotlib.pyplot as plt
import seaborn as sns

top_features = imp.head(5).index 

for col in top_features:
    plt.figure()
    sns.kdeplot(real_X[col], label="real")
    sns.kdeplot(syn_X[col], label="synthetic")
    plt.title(col)
    plt.legend()
    plt.show()

# %% [markdown]
# # Correlation Differnce

# %%
real_X[top_features].corr()
syn_X[top_features].corr()

diff = real_X[top_features].corr() - syn_X[top_features].corr()
sns.heatmap(diff, annot=True, cmap="coolwarm", center=0)
display(Markdown("Synthetic correlationss are weaker. THus weakening dependence between top features."))
# Out:
# Synthetic correlationss are weaker. THus weakening dependence between top features.

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2, random_state=0)
Z_real = pca.fit_transform(oX)
Z_syn  = pca.transform(syn_X)

plt.figure()
plt.scatter(Z_real[:,0], Z_real[:,1], alpha=0.6, label="Real")
plt.scatter(Z_syn[:,0],  Z_syn[:,1],  alpha=0.6, label="Synthetic")
plt.title("PCA (fit on real): projection of real vs synthetic")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.legend()
plt.tight_layout()
plt.savefig("hiv_pca_realfit.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
import numpy as np

rng = np.random.default_rng(0)
n = min(len(real_X), len(syn_X))
idx_r = rng.choice(len(real_X), size=n, replace=False)
idx_s = rng.choice(len(syn_X),  size=n, replace=False)

Xr = real_X[idx_r]
Xs = syn_X[idx_s]

Cr = np.corrcoef(Xr, rowvar=False)
Cs = np.corrcoef(Xs, rowvar=False)
D  = Cs - Cr

np.fill_diagonal(D, 0.0)

# clip extreme display to see structure, not noise
v = np.quantile(np.abs(D), 0.95)   # robust scale


import matplotlib.pyplot as plt

plt.figure(figsize=(7,6))
plt.imshow(D, aspect="auto", vmin=-v, vmax=v)
plt.colorbar(label="corr(syn) - corr(real)")
plt.title(f"Correlation difference heatmap (clipped at 95% |Δ|={v:.2f})")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 8
#       5 idx_r = rng.choice(len(real_X), size=n, replace=False)
#       6 idx_s = rng.choice(len(syn_X),  size=n, replace=False)
# ----> 8 Xr = real_X[idx_r]
#       9 Xs = syn_X[idx_s]
#
# File c:\Users\tonyt\MATH4600_VAE\.venv\Lib\site-packages\pandas\core\frame.py:4384, in DataFrame.__getitem__(self, key)
#    4382     if is_iterator(key):
#    4383         key = list(key)
# -> 4384     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4386 # take() does not accept boolean indexers
#    4387 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\tonyt\MATH4600_VAE\.venv\Lib\site-packages\pandas\core\indexes\base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
#    6300     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6302 self._raise_if_missing(keyarr, indexer, axis_name)
#    6304 keyarr = self.take(indexer)
#    6305 if isinstance(key, Index):
#    6306     # GH 42790 - Preserve name from an Index
#
# File c:\Users\tonyt\MATH4600_VAE\.venv\Lib\site-packages\pandas\core\indexes\base.py:6352, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6350 if nmissing:
#    6351     if nmissing == len(indexer):
# -> 6352         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6354     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6355     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index([44, 38, 21, 13, 88, 26, 87, 55, 72, 54, 63, 41, 67, 57, 61, 70, 77,  8,\n       83, 75, 28, 69,  0, 22, 56, 39, 65, 17, 42, 12,  1, 37,  6, 89, 64, 36,\n       51, 50, 90, 78, 20, 73, 27, 16,  2, 79, 35,  9, 43, 33, 46, 15, 47, 82,\n       76, 74, 85, 11, 58, 71, 34,  3, 48, 14, 45, 52, 81, 30, 59, 10, 40, 24,\n       49, 84,  5, 66, 60, 18, 25, 86, 32, 68, 31,  7,  4, 53, 62, 19, 23, 80,\n       29],\n      dtype='int64')] are in the [columns]"
